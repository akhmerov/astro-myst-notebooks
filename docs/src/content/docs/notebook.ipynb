# %% [markdown]
# ---
# title: Notebook source
# description: A Jupyter notebook published and executed like a MyST page.
# ---
#
# This page is `notebook.ipynb`. Its Markdown cells become prose and its code
# cells execute in a fresh kernel during the build, exactly like a `.md` page.

# %%
squares = [k * k for k in range(1, 6)]
print(squares)

# %% [markdown]
# Stored outputs in the file are ignored; the published results below come from
# the build. The list has {eval}`len(squares)` entries, and a link to the
# [walkthrough](walkthrough.md#triangular-sum) resolves like one from a `.md` page.

# %%
sum(squares)

# %% [raw]
# Raw cells are not published.
